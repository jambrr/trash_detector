# %%
import json
import os
import re
import shutil
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
import cv2
from pycocotools import mask as maskUtils
import random
import pandas as pd
from PIL import Image

#Data Preprocessing
def convert_2_yolo(json_file, output_dir="./datasets/TACO/"):
    with open(json_file, 'r') as f:
        data = json.load(f)

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for ann in data['annotations']:
        image_id = ann['image_id']
        image_info = data['images'][image_id]
        file_name = image_info['file_name']
        #formatted_filename = re.search(r"(\d+)\.jpg", file_name).group(1)
        #formatted_filename = os.path.splitext(filename_formatting(file_name))[0] + '.txt'
        formatted_filename = os.path.splitext(file_name)[0] + '.txt'
        img_width = image_info['width']
        img_height = image_info['height']
        yolo_annotations = []

        class_id = ann['category_id']
        segmentation = ann['segmentation'][0]
        bbox = ann['bbox']  # Assuming bbox format is [xmin, ymin, xmax, ymax]
        x1, y1, w, h = bbox
        
        # Normalize label values
        x_center = (x1 + w/2) / img_width
        y_center = (y1 + h/2) / img_height
        w = w / img_width
        h = h / img_height

        # Prepare the YOLO format line
        #yolo_annotations.append(f"{class_id} {x_center:.6f} {y_center:.6f} {w:.6f} {h:.6f}")

        normalized_coords = normalize_segments(segmentation, img_width, img_height)
        row = f"{class_id} " + " ".join([f"{coord:.6f}" for coord in normalized_coords]) + "\n"
        yolo_annotations.append(row)

        # Write annotations to a file in the YOLO format
        output_file = os.path.join(output_dir, formatted_filename)
        with open(output_file, 'a') as out_f:
            out_f.write(row)

        print(f"YOLO format annotations saved for image {image_id}")

def filename_formatting(filename):
    basename, image_name = filename.split("/")
    new_filename = str.lower(f"{basename}-{image_name}")

    return new_filename

def move_and_rename(filename, input_dir="./datasets/TACO/data", output_dir="./datasets/TACO/all_images/"):
    with open(filename, 'r') as f:
        data = json.load(f)

    if not os.path.exists(output_dir):
        os.makedirs(output_dir, exist_ok=True)

    for ann in data['annotations']:
        image_id = ann['image_id']
        image_info = data['images'][image_id]
        filename = image_info['file_name']

        new_filename = filename_formatting(filename)

        src = os.path.join(input_dir, filename)
        dest = os.path.join(output_dir, new_filename)

        if os.path.exists(output_dir):
            shutil.copy(src, dest)
            print(f"Image moved to: {output_dir}")
        else:
            print(f"Source image not found: {input_dir}")

def normalize_segments(coords, img_width, img_height):
    normalized = []
    for i in range(0, len(coords), 2):
        x = coords[i] / img_width
        y = coords[i + 1] / img_height
        normalized.append(x)
        normalized.append(y)
    return normalized

def normalize_bbox(coords, img_width, img_height):
    normalized = []
    for i in range(0, len(coords), 2):
        x = coords[i] / img_width
        y = coords[i + 1] / img_height
        normalized.append(x)
        normalized.append(y)
 
def data_splitting(filename="./datasets/TACO/annotations.json", all_labels="./datasets/TACO/tmp/labels", all_images="./datasets/TACO/tmp/images", train_dir="./datasets/TACO/train/", val_dir="./datasets/TACO/val/"):
    with open(filename, 'r') as f:
        data = json.load(f)

    filenames = []
    labels = []

    for ann in data['annotations']:
        image_id = ann['image_id']
        image_info = data['images'][image_id]
        filename = filename_formatting(image_info['file_name'])
        label = os.path.splitext(filename)[0] + '.txt'

        filenames.append(filename)
        labels.append(label)


    filename_ds = np.array(filenames)
    labels_ds = np.array(labels)

    X_train, X_val, y_train, y_val = train_test_split(filename_ds, labels_ds, test_size=0.2, shuffle=True)

    for i in X_train:
        shutil.copy(all_images+i, train_dir+"tmp/images/"+i)
    for i in y_train:
        shutil.copy(all_labels+i, train_dir+"labels/"+i)
    for i in X_val:
        shutil.copy(all_images+i, val_dir+"images/"+i)
    for i in y_val:
        shutil.copy(all_labels+i, val_dir+"labels/"+i)

def empty_directory(directory_path):
    # Check if the directory exists
    if os.path.exists(directory_path):
        # Iterate over all the files and directories within the given directory
        for filename in os.listdir(directory_path):
            file_path = os.path.join(directory_path, filename)
            
            # Check if it's a file or directory
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.remove(file_path)  # Remove the file
                print(f"Deleted file: {file_path}")
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)  # Remove the directory
                print(f"Deleted directory: {file_path}")
    else:
        print(f"Directory {directory_path} does not exist!")

def convert_image_bw(input_dir, label_dir, output_dir=None):
    # Ensure the output directory exists
    if output_dir is None:
        output_dir = input_dir

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Loop through all files in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith((".jpg", ".png")):
            # Full path to the image
            img_path = os.path.join(input_dir, filename)
    
            # Load the image
            image = cv2.imread(img_path)
    
            if image is not None:  # Check if the image is loaded successfully
                # Convert the image to grayscale
                gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                new_filename = add_prefix("bw", filename)
    
                # Create the output file path
                output_path = os.path.join(output_dir, new_filename)
    
                # Save the grayscale image
                cv2.imwrite(output_path, gray_image)

                #old_label = os.path.splitext(filename)[0] + '.txt'
                #new_label = f"bw-{old_label}"

                # Add a new label file too
                #shutil.copy(label_dir+old_label, label_dir+new_label)
                print(f'Converted {filename} to grayscale.')
            else:
                print(f'Failed to load {filename}')
    
    copy_files_with_new_names(label_dir, prefix='bw_')
    print("All images have been processed.")

def copy_files_with_new_names(input_dir, output_dir=None, prefix='', suffix=''):
    # If no output directory is provided, use the input directory
    if output_dir is None:
        output_dir = input_dir

    # Ensure the output directory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Loop through all files in the input directory
    for filename in os.listdir(input_dir):
        file_path = os.path.join(input_dir, filename)

        # Check if the current file is a regular file (not a directory)
        if os.path.isfile(file_path):
            # Split the filename and extension
            file_name, file_ext = os.path.splitext(filename)

            # Create the new filename with prefix or suffix
            new_filename = f"{prefix}{file_name}{suffix}{file_ext}"

            # Create the new file path
            new_file_path = os.path.join(output_dir, new_filename)

            # Copy the file to the new location with the new name
            shutil.copy(file_path, new_file_path)
            print(f"Copied {filename} to {new_filename}")

    print("All files have been copied and renamed.")

def flip_image(image, direction):
    """
    Augments the image by flipping it vertically and horizontally.

    Parameters:
    - image: The input image as a NumPy array.

    Returns:
    - original: The original image.
    - vertical_flip: The vertically flipped image.
    - horizontal_flip: The horizontally flipped image.
    - both_flips: The image flipped both vertically and horizontally.
    """
    
    # Ensure the input is a valid image
    if image is None:
        raise ValueError("Input image is None.")
    
    # Flip the image vertically
    flipped_image = cv2.flip(image, direction)  # 0 means flipping around the x-axis

    return flipped_image

def flip_augmentation(directory):
    """
    Applies augmentation to images with the 'original_' prefix in the specified directory.

    Parameters:
    - directory: Path to the directory containing images.
    """
    for filename in os.listdir(directory):
        if filename.startswith("original_") and filename.endswith((".jpg", ".png")):
            # Load the image
            image_path = os.path.join(directory, filename)
            image = cv2.imread(image_path)
            
            if image is not None:
                # Perform augmentation
                vertical_flip = flip_image(image, 0)
                horizontal_flip = flip_image(image, 1)
                
                # Save augmented images with modified names
                cv2.imwrite(os.path.join(directory, f"vertical_flip_{filename}"), vertical_flip)
                cv2.imwrite(os.path.join(directory, f"horizontal_flip_{filename}"), horizontal_flip)
                
                print(f'Augmented {filename} and saved flips.')
            else:
                print(f'Failed to load {filename}')

def add_prefix(prefix, filename):
    return f"{prefix}_{filename}"

#Augmentation functions
def add_noise(image, noise_ratio=0.001):
    noisy_image = image.copy()
    num_noisy_pixels = int(noise_ratio * image.shape[0] * image.shape[1])

    x_coords = np.random.randint(0, image.shape[1], num_noisy_pixels)
    y_coords = np.random.randint(0, image.shape[0], num_noisy_pixels)

    noisy_image[y_coords, x_coords] = np.random.randint(0, 256, (num_noisy_pixels, 3))

    return noisy_image

def apply_noise(image_dir, label_dir, strength):
    for filename in os.listdir(image_dir):
        if filename.startswith("original_"):
            image_path = os.path.join(image_dir, filename)
            image = cv2.imread(image_path)

            noisy_image = add_noise(image, noise_ratio=strength)
            new_filename = add_prefix("noise", filename)
            new_filepath = os.path.join(image_dir, new_filename)
            cv2.imwrite(new_filepath, noisy_image)

            print("Creating noisy image")

    copy_files_with_new_names(label_dir, prefix='noise_')

def add_saturation(image, saturation_change=None):
    if saturation_change is None:
        saturation_change = np.random.uniform(-0.25, 0.25)

    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV).astype(np.float32)
    hsv_image[:, :, 1] *= (1 + saturation_change)
    hsv_image[:, :, 1] = np.clip(hsv_image[:, :, 1], 0, 255)
    adjusted_image = cv2.cvtColor(hsv_image.astype(np.uint8), cv2.COLOR_HSV2BGR)

    return adjusted_image

def add_exposure(image, exposure_percent=0):
    exposure_percent = np.clip(exposure_percent, -10, 10)
    exposure_factor = 1 + (exposure_percent / 100.0)
    exposure_adjusted_image = cv2.convertScaleAbs(image, alpha=exposure_factor)

    return exposure_adjusted_image

def apply_exposure(image_dir, label_dir):
    for filename in os.listdir(image_dir):
        if filename.startswith("original_"):
            image_path = os.path.join(image_dir, filename)
            image = cv2.imread(image_path)

            exposed_image = add_exposure(image)
            new_filename = add_prefix("exposed", filename)
            new_filepath = os.path.join(image_dir, new_filename)
            cv2.imwrite(new_filepath, exposed_image)

            print("Creating noisy image")

    copy_files_with_new_names(label_dir, prefix='exposed_')

def apply_saturation(image_dir, label_dir):
    for filename in os.listdir(image_dir):
        if filename.startswith("original_"):
            image_path = os.path.join(image_dir, filename)
            image = cv2.imread(image_path)

            saturated_image = add_saturation(image)
            new_filename = add_prefix("saturated", filename)
            new_filepath = os.path.join(image_dir, new_filename)
            cv2.imwrite(new_filepath, saturated_image)

            print("Creating noisy image")

    copy_files_with_new_names(label_dir, prefix='saturated_')


def apply_seg_mask(image_dir, label_dir, output_dir=None, background_image_path=None):
    if output_dir is None:
        output_dir = image_dir

    for filename in os.listdir(image_dir):
        if filename.startswith("original_"):
            image_path = os.path.join(image_dir, filename)
            image = cv2.imread(image_path)
            mask = np.zeros(image.shape[:2], dtype=np.uint8)
            height, width = image.shape[:2]
            label_path = os.path.join(label_dir, os.path.splitext(filename)[0] + '.txt')

            with open(label_path, 'r') as f:
                lines = f.readlines()
                for line in lines:
                    data = line.strip().split()
                    class_id = int(data[0])
                    polygon = np.array([[float(x) * width, float(y) * height] for x, y in zip(data[1::2], data[2::2])], dtype=np.int32)
                    cv2.fillPoly(mask, [polygon], color=(class_id + 1))

            masked_image = cv2.bitwise_and(image, image, mask=mask)

            if background_image_path:
                background = cv2.imread(background_image_path)
                background = cv2.resize(background, (image.shape[1], image.shape[0]))
            
            else: 
                background = np.zeros_like(image)
                background[:] = (0, 255, 0)

            inverted_mask = cv2.bitwise_not(mask)
            background_part = cv2.bitwise_and(background, background, mask=inverted_mask)
            final_image = cv2.add(masked_image, background_part)
            new_filename = add_prefix("no_background", filename)

            new_filepath = os.path.join(output_dir, new_filename)

            cv2.imwrite(new_filepath, final_image)

    copy_files_with_new_names(label_dir, prefix='no_background-')
   

def replace_classes_in_json(input_json_path, output_json_path, class_mapping):
    """
    Replaces class annotations in a COCO-style JSON file using a specified class mapping and writes the result to a new JSON file.

    Parameters:
    - input_json_path (str): Path to the input JSON file.
    - output_json_path (str): Path to the output JSON file where updated annotations will be saved.
    - class_mapping (dict): Dictionary mapping old class IDs to new class IDs.
    """
    # Load the original JSON data
    with open(input_json_path, 'r') as f:
        data = json.load(f)
    
    # Replace class IDs in each annotation
    for annotation in data.get('annotations', []):
        # Update 'category_id' if it exists in class_mapping
        if annotation['category_id'] in class_mapping:
            annotation['category_id'] = class_mapping[annotation['category_id']]
    
    # Write the updated data to a new JSON file
    with open(output_json_path, 'w') as f:
        json.dump(data, f, indent=4)
    
    print(f"Updated annotations saved to {output_json_path}")


def rename_files_with_prefix(directory, prefix="original_"):
    """
    Renames every file in the specified directory by adding a prefix to the filename.

    Parameters:
    - directory: The directory containing files to rename.
    - prefix: The prefix to add to each filename (default is "original_").
    """
    # Ensure the directory exists
    if not os.path.isdir(directory):
        raise ValueError("Directory does not exist.")

    # Loop through each file in the directory
    for filename in os.listdir(directory):
        # Create the full path for the current file
        old_path = os.path.join(directory, filename)

        # Skip directories
        if os.path.isfile(old_path):
            # Create the new filename with the prefix
            new_filename = prefix + filename
            new_path = os.path.join(directory, new_filename)

            # Rename the file
            os.rename(old_path, new_path)
            print(f'Renamed {filename} to {new_filename}')

import pickle

def find_images_without_labels(image_dir, label_dir, image_extensions=['.jpg', '.jpeg', '.png']):
    """
    Lists images in `image_dir` that have no corresponding label file in `label_dir`.

    Parameters:
    - image_dir (str): Path to the directory containing image files.
    - label_dir (str): Path to the directory containing label files.
    - image_extensions (list): List of image file extensions to consider (e.g., ['.jpg', '.png']).

    Returns:
    - List of image file names without corresponding label files.
    """
    # List all images in the image directory
    image_files = [f for f in os.listdir(image_dir) if os.path.splitext(f)[1].lower() in image_extensions]

    # List all label files in the label directory
    label_files = [os.path.splitext(f)[0] for f in os.listdir(label_dir) if f.endswith('.txt')]

    # Find images without corresponding labels
    images_without_labels = [img for img in image_files if os.path.splitext(img)[0] not in label_files]

    return images_without_labels

def remove_images_without_labels(image_dir, label_dir, image_extensions=['.jpg', '.jpeg', '.png']):
    """
    Removes images in `image_dir` that have no corresponding label file in `label_dir`.

    Parameters:
    - image_dir (str): Path to the directory containing image files.
    - label_dir (str): Path to the directory containing label files.
    - image_extensions (list): List of image file extensions to consider (e.g., ['.jpg', '.png']).

    Returns:
    - List of deleted image file names.
    """
    # List all images in the image directory
    image_files = [f for f in os.listdir(image_dir) if os.path.splitext(f)[1].lower() in image_extensions]
    
    # List all label files in the label directory
    label_files = {os.path.splitext(f)[0] for f in os.listdir(label_dir) if f.endswith('.txt')}
    
    # Find images without corresponding labels and remove them
    deleted_images = []
    for img in image_files:
        img_name = os.path.splitext(img)[0]
        if img_name not in label_files:
            img_path = os.path.join(image_dir, img)
            os.remove(img_path)
            deleted_images.append(img)
            print(f"Deleted: {img_path}")
    
    return deleted_images

def create_labels_from_csv(csv_file, images_dir, label_dir, class_mapping):
    """
    Creates label files in YOLO format from a CSV file, dynamically reading image dimensions.

    Parameters:
    - csv_file (str): Path to the CSV file containing bounding boxes and class names.
    - images_dir (str): Directory where the images are stored.
    - label_dir (str): Directory to save the generated label files.
    - class_mapping (dict): Mapping of class names to class indices (e.g., {'metal': 0, 'plastic': 1}).
    """
    # Ensure label directory exists
    os.makedirs(label_dir, exist_ok=True)

    # Load CSV file
    data = pd.read_csv(csv_file)

    # Process each row and create a label file
    for _, row in data.iterrows():
        image_name = row['image_name']
        x_min = row['x_min']
        y_min = row['y_min']
        x_max = row['x_max']
        y_max = row['y_max']
        class_name = row['class_name']

        # Construct the full image path
        image_path = os.path.join(images_dir, image_name)

        # Check if image exists
        if not os.path.exists(image_path):
            print(f"Warning: Image '{image_name}' not found. Skipping.")
            continue

        # Get image dimensions
        with Image.open(image_path) as img:
            img_width, img_height = img.size

        # Convert bounding box coordinates to YOLO format
        x_center = (x_min + x_max) / 2 / img_width
        y_center = (y_min + y_max) / 2 / img_height
        width = (x_max - x_min) / img_width
        height = (y_max - y_min) / img_height

        # Get class index from the class name
        class_index = class_mapping.get(class_name)
        if class_index is None:
            print(f"Warning: Class '{class_name}' not found in class mapping. Skipping.")
            continue

        # Create label file path
        formatted_filename = os.path.splitext(image_name)[0] + '.txt'
        label_file_path = os.path.join(label_dir, formatted_filename)

        # Write label in YOLO format
        with open(label_file_path, 'a') as f:
            f.write(f"{class_index} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n")

        print(f"Label created for {image_name}")

if __name__== "__main__":
    batch_annotations = "./datasets/TACO/batch_1/annotations.json"
    all_annotations = "./datasets/TACO/data/annotations.json"
    all_labels = "./datasets/TACO/all_labels"
    all_images = "./datasets/TACO/all_images"
    
    #trashnet - training
    trashnet_img_output = "./datasets/trashnet/train/labels"
    trashnet_annotations = "./datasets/trashnet/train/_annotations.coco.json"

    #trashnet - validation
    trashnet_val_output = "./datasets/trashnet/valid/labels"
    trashnet_val_annotations = "./datasets/trashnet/valid/_annotations.coco.json"

    taco_aug_label_train = "./datasets/taconet/train/labels" 
    taco_aug_label_val = "./datasets/taconet/val/labels" 

    #empty_directory("./datasets/TACO/val/images")
    #empty_directory("./datasets/TACO/val/labels")
    #empty_directory("./datasets/TACO/train/images")
    #empty_directory("./datasets/TACO/train/labels")

    #convert_2_yolo("./datasets/TACO/new_ann.json", output_dir="./datasets/TACO/tmp/labels")
    #convert_2_yolo("./datasets/trashnet/valid/new_ann.json", output_dir="./datasets/trashnet/valid/labels")
    #convert_2_yolo("./datasets/trashnet/train/new_ann.json", output_dir="./datasets/trashnet/train/labels")
    #move_and_rename(all_annotations)
    #data_splitting()
    convert_image_bw("./datasets/taconet/train/images", taco_aug_label_train)
    #convert_image_bw("./datasets/taconet/val/images", taco_aug_label_val)

    # copy_files_with_new_names("./datasets/trashnet/tmp/images", output_dir="./datasets/taconet/tmp/images", prefix='trashnet-')
    # copy_files_with_new_names("./datasets/trashnet/tmp/labels", output_dir="./datasets/taconet/tmp/labels", prefix='trashnet-')
    # copy_files_with_new_names("./datasets/TACO/tmp/images", output_dir="./datasets/taconet/tmp/images", prefix='taco-')
    # copy_files_with_new_names("./datasets/TACO/tmp/labels", output_dir="./datasets/taconet/tmp/labels", prefix='taco-')

    #apply_seg_mask("./datasets/waste/train/images", label_dir="./datasets/waste/train/labels")
    #apply_seg_mask("./datasets/waste/val/images", label_dir="./datasets/waste/val/labels")
    #rename_files_with_prefix("./datasets/waste/train/labels")
    #rename_files_with_prefix("./datasets/waste/train/images")
    #flip_augmentation("./datasets/TACO_aug/train/images")
    #copy_files_with_new_names("./datasets/TACO_aug/train/labels", prefix='-')

    #rename_files_with_prefix("./datasets/waste/val/images")
    #rename_files_with_prefix("./datasets/waste/val/labels")
    #flip_augmentation("./datasets/TACO_aug/val/images")
    #rename_files_with_prefix("./datasets/taco4/train/images", prefix='taco-')
    #rename_files_with_prefix("./datasets/taco4/train/labels", prefix='taco-')
    #rename_files_with_prefix("./datasets/taco4/val/images", prefix='taco-')
    #rename_files_with_prefix("./datasets/taco4/val/labels", prefix='taco-')

    #apply_noise("./datasets/TACO_aug/train/images", taco_aug_label_train, 0.3)
    #apply_noise("./datasets/TACO_aug/val/images", taco_aug_label_val, 0.3)

    #apply_exposure("./datasets/TACO_aug/train/images", taco_aug_label_train)
    #apply_exposure("./datasets/TACO_aug/val/images", taco_aug_label_val)
    #apply_saturation("./datasets/TACO_aug/train/images", taco_aug_label_train)

    import splitfolders
    #splitfolders.ratio('./datasets/AquaTrash/tmp/', output="./datasets/AquaTrash", seed=4321, ratio=(.8, .2))
    
    class_mapping = {
        0: 1,  # Aluminium foil -> Metals
        2: 1,  # Aluminium blister pack -> Metals
        8: 1,  # Metal bottle cap -> Metals
        10: 1, # Food Can -> Metals
        11: 1, # Aerosol -> Metals
        12: 1, # Drink can -> Metals
        28: 1, # Metal lid -> Metals
        50: 1, # Pop tab -> Metals
        52: 1, # Scrap metal -> Metals
        4: 4,   # Other plastic bottle -> Plastic
        5: 4,   # Clear plastic bottle -> Plastic
        7: 4,   # Plastic bottle cap -> Plastic
        21: 4,  # Disposable plastic cup -> Plastic
        22: 4,  # Foam cup -> Plastic
        24: 4,  # Other plastic cup -> Plastic
        27: 4,  # Plastic lid -> Plastic
        29: 4,  # Other plastic -> Plastic
        35: 4,  # Plastified paper bag -> Plastic
        36: 4,  # Plastic film -> Plastic
        37: 4,  # Six pack rings -> Plastic
        38: 4,  # Garbage bag -> Plastic
        39: 4,  # Other plastic wrapper -> Plastic
        40: 4,  # Single-use carrier bag -> Plastic
        41: 4,  # Polypropylene bag -> Plastic
        42: 4,  # Crisp packet -> Plastic
        43: 4,  # Spread tub -> Plastic
        44: 4,  # Tupperware -> Plastic
        45: 4,  # Disposable food container -> Plastic
        46: 4,  # Foam food container -> Plastic
        47: 4,  # Other plastic container -> Plastic
        48: 4,  # Plastic gloves -> Plastic
        49: 4,  # Plastic utensils -> Plastic
        54: 4,  # Squeezable tube -> Plastic
        55: 4,  # Plastic straw -> Plastic
        57: 4,  # Styrofoam piece -> Plastic
        3: 2,   # Carded blister pack -> Cardboard
        13: 2,  # Toilet tube -> Cardboard
        14: 2,  # Other carton -> Cardboard
        15: 2,  # Egg carton -> Cardboard
        16: 2,  # Drink carton -> Cardboard
        17: 2,  # Corrugated carton -> Cardboard
        18: 2,  # Meal carton -> Cardboard
        19: 2,  # Pizza box -> Cardboard
        20: 2,  # Paper cup -> Cardboard
        30: 2,  # Magazine paper -> Cardboard
        31: 2,  # Tissues -> Cardboard
        32: 2,  # Wrapping paper -> Cardboard
        33: 2,  # Normal paper -> Cardboard
        34: 2,  # Paper bag -> Cardboard
        56: 2,
        6: 6,  # Glass bottle -> Glass
        9: 6,  # Broken glass -> Glass
        23: 6, # Glass cup -> Glass
        26: 6,
        51: 3,  # Rope & strings -> Textile
        53: 3,
        1: 0,
        25: 7,
        58: 8,
        59: 5
    }

    class_mapping2 = {
        0:8,
        5:4,
        3:2,
    }

    class_mapping3 = {
        'glass': 0,
        'paper': 1,
        'metal': 2,
        'plastic': 3
    }
    
    #create_labels_from_csv("./datasets/AquaTrash/annotations.csv", "./datasets/AquaTrash/tmp/images", "./datasets/AquaTrash/tmp/labels", class_mapping3)
    # Call the function
    #replace_classes_in_json("./datasets/trashnet/valid/_annotations.coco.json", "./datasets/trashnet/valid/new_ann.json", class_mapping2)
    #replace_classes_in_json("./datasets/trashnet/train/_annotations.coco.json", "./datasets/trashnet/train/new_ann.json", class_mapping2)
    #replace_classes_in_json("./datasets/TACO/data/annotations.json", "./datasets/TACO/new_ann.json", class_mapping)

    #remove_images_without_labels("datasets/trashnet/valid/images", "datasets/trashnet/valid/labels")
    images = find_images_without_labels("datasets/AquaTrash/tmp/images", "datasets/AquaTrash/tmp/labels")
    # images = find_images_without_labels("datasets/trashnet/valid/images", "datasets/trashnet/valid/labels")

    for i in images:
        print(i)
    print(len(images))
# Out:
# Converted trashnet-mixed10-16_42_jpg.rf.22e178a17f43fcf69b9a6efb24a0ab17.jpg to grayscale.
# Converted trashnet-2020_0328_53_jpg.rf.589079ed7b96ebf2753ec233aa413d22.jpg to grayscale.
# Converted taco-batch_1-000064.jpg to grayscale.
# Converted taco-batch_7-000137.jpg to grayscale.
# Converted taco-batch_13-000039.jpg to grayscale.
# Converted taco-batch_10-000074.jpg to grayscale.
# Converted trashnet-metal_280_jpg.rf.0954c55ba9a846a54eaa838d23d0d8ea.jpg to grayscale.
# Converted taco-batch_15-000010.jpg to grayscale.
# Converted taco-batch_4-000050.jpg to grayscale.
# Converted taco-batch_14-000081.jpg to grayscale.
# Converted taco-batch_5-000007.jpg to grayscale.
# Converted taco-batch_1-000095.jpg to grayscale.
# Converted trashnet-plastic_container_145_jpg.rf.1fe9662f226e746e3bc9afe9e0cc9c6a.jpg to grayscale.
# Converted trashnet-mixed10-16_39_jpg.rf.41e377f6c80487cc0757a9981a6a9db0.jpg to grayscale.
# Converted taco-batch_6-000082.jpg to grayscale.
# Converted trashnet-mixed09-16_206_jpg.rf.f543ad8a6423ca5e715e07f4dc70c9fc.jpg to grayscale.
# Converted trashnet-mixed2-LCM_143_jpg.rf.32543092fcead3c632fb555fc306ee67.jpg to grayscale.
# Converted trashnet-mixed_279_jpg.rf.243b67c7a4dd528d1b2a8fbf1f494f16.jpg to grayscale.
# Converted trashnet-mixed10-15-C_473_jpg.rf.5b6c826ba138b83eda343afac36c359e.jpg to grayscale.
# Converted trashnet-mixed3-HCM_205_jpg.rf.aaf486241df5ed104ac583e33d76a803.jpg to grayscale.
# Converted trashnet-mixed09-16_113_jpg.rf.013cf9178088ca7f135ce75787d23b28.jpg to grayscale.
# Converted trashnet-plastic_container_098_jpg.rf.41482b96eeecbd6da72a6cf69e4d2a53.jpg to grayscale.
# Converted trashnet-metal_090_jpg.rf.c77c0c21d4725d7d70bbc3548f8aba3b.jpg to grayscale.
# Converted trashnet-mixed2-LCS_082_jpg.rf.6ab2f04d45cc9cfae4d4cfb2ca6cdaae.jpg to grayscale.
# Converted trashnet-mixed_129_jpg.rf.66b75ecdb3aedaccca05a363a5688021.jpg to grayscale.
# Converted trashnet-mixed3-HCS_114_jpg.rf.c6a76b14d4e6ea8eb019b4679ddec560.jpg to grayscale.
# Converted trashnet-mixed3-HCS_191_jpg.rf.93011576bbda5652d1e2979477eb2d5a.jpg to grayscale.
# Converted taco-batch_5-000034.jpg to grayscale.
# Converted trashnet-metal_152_jpg.rf.1c9512523662f63b506ba4a1b50e248c.jpg to grayscale.
# Converted taco-batch_7-000078.jpg to grayscale.
# Converted taco-batch_8-000078.jpg to grayscale.
# Converted trashnet-mixed3-HCM_058_jpg.rf.e517ff0afbbca02def31a2c5370731d4.jpg to grayscale.
# Converted trashnet-mixed2-LCM_227_jpg.rf.055bf250444ec8e83eb2e997f4268cf7.jpg to grayscale.
# Converted trashnet-paper_container_099_jpg.rf.2c163fcb91d548b750d9f74b0d5fc3cd.jpg to grayscale.
# Converted trashnet-mixed09-16_337_jpg.rf.b40041661497da82db18a8ca1f630dbc.jpg to grayscale.
# Converted taco-batch_10-000096.jpg to grayscale.
# Converted trashnet-mixed10-15-C_454_jpg.rf.0d7c907b55467e18af561504043ecac4.jpg to grayscale.
# Converted taco-batch_4-000046.jpg to grayscale.
# Converted taco-batch_14-000061.jpg to grayscale.
# Converted trashnet-carton_017_jpg.rf.5b8f08d14f734bda6d280f8dc8dd7c08.jpg to grayscale.
# Converted trashnet-metal_272_jpg.rf.1e83b9a4468580e60fafe3c2662d9ae4.jpg to grayscale.
# Converted trashnet-mixed09-16_257_jpg.rf.b97fca978b4b570e8832b96fb05fdb93.jpg to grayscale.
# Converted taco-batch_11-000064.jpg to grayscale.
# Converted trashnet-mixed_215_jpg.rf.0a9b7aa5a5322e2a840cc66e648b28d1.jpg to grayscale.
# Converted trashnet-mixed09-16_088_jpg.rf.af9961a2254f1743793b0544246c4e5e.jpg to grayscale.
# Converted taco-batch_11-000080.jpg to grayscale.
# Converted taco-batch_2-000034.jpg to grayscale.
# Converted trashnet-mixed3-HCM_267_jpg.rf.d722dea06521f786a4f7a05c5c0fe64f.jpg to grayscale.
# Converted trashnet-mixed3-HCS_132_jpg.rf.a0893386093f4eec1f6d3adb3bbf81a7.jpg to grayscale.
# Converted trashnet-mixed2-LCM_076_jpg.rf.5bf9ff4ca61f3845832ae3baad1cc05b.jpg to grayscale.
# Converted trashnet-mixed_043_jpg.rf.840597a92c7164590f590581b5989881.jpg to grayscale.
# Converted trashnet-metal_013_jpg.rf.0d95b21ee304b80090c6e5bedce2fac0.jpg to grayscale.
# Converted taco-batch_1-000092.jpg to grayscale.
# Converted trashnet-mixed10-15-C_262_jpg.rf.47da1a03cf5ea224115bb24e71c0d222.jpg to grayscale.
# Converted trashnet-mixed10-15-C_422_jpg.rf.e19284e96db4e75b920cdd7f35133511.jpg to grayscale.
# Converted trashnet-mixed3-HCM_079_jpg.rf.e837b01f0a06b519a723495a8c37b0df.jpg to grayscale.
# Converted trashnet-mixed10-15-C_312_jpg.rf.f339459ea07b66cb6edac62ca430af86.jpg to grayscale.
# Converted taco-batch_13-000034.jpg to grayscale.
# Converted trashnet-mixed_277_jpg.rf.661ef3703be445d86267558fbb9048f7.jpg to grayscale.
# Converted taco-batch_14-000098.jpg to grayscale.
# Converted trashnet-mixed10-15-C_55_jpg.rf.14d89c04b31eb889a81f16ad39860fc2.jpg to grayscale.
# Converted taco-batch_12-000027.jpg to grayscale.
# Converted trashnet-mixed10-15-C_199_jpg.rf.df8bf31ec51a05c97de1b0dab59b8304.jpg to grayscale.
# Converted taco-batch_13-000070.jpg to grayscale.
# Converted taco-batch_4-000062.jpg to grayscale.
# Converted trashnet-metal_045_jpg.rf.9ff2629a61f6def3acb4d45fbaa6100d.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_65_jpg.rf.9285592d375d91a7f660f89dd96d12c4.jpg to grayscale.
# Converted trashnet-metal_209_jpg.rf.6211aaecb1e750959c41ccb3d88b41a7.jpg to grayscale.
# Converted taco-batch_4-000021.jpg to grayscale.
# Converted trashnet-mixed3-HCM_045_jpg.rf.38165e019192697139ae5fc19cda455e.jpg to grayscale.
# Converted trashnet-mixed2-LCS_052_jpg.rf.4b7fc0a1d9465ef364d1bba241e8f29f.jpg to grayscale.
# Converted taco-batch_5-000119.jpg to grayscale.
# Converted trashnet-mixed2-LCM_294_jpg.rf.8251a59c4e1982f8581349072041a100.jpg to grayscale.
# Converted trashnet-mixed3-HCM_090_jpg.rf.9db85d62f69aa2d0a716d906b7e47d09.jpg to grayscale.
# Converted taco-batch_12-000098.jpg to grayscale.
# Converted taco-batch_13-000096.jpg to grayscale.
# Converted trashnet-mixed3-HCM_169_jpg.rf.bac4b62cf1ab41082bf01c76aa211b69.jpg to grayscale.
# Converted trashnet-plastic_bottle_037_jpg.rf.768780532040a69370f449fcd2e0918b.jpg to grayscale.
# Converted taco-batch_5-000052.jpg to grayscale.
# Converted trashnet-mixed10-15-C_104_jpg.rf.96e76db2e886c4ddf8833422d49d7d2c.jpg to grayscale.
# Converted taco-batch_9-000085.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_141_jpg.rf.67bd016a9563d1329b32496011ceb9ba.jpg to grayscale.
# Converted trashnet-metal_068_jpg.rf.35fb1718b2197d205a15fb275cab08c8.jpg to grayscale.
# Converted trashnet-mixed2-LCS_190_jpg.rf.7dd32026001eba0610ffa6932f3dc7d5.jpg to grayscale.
# Converted trashnet-mixed_223_jpg.rf.293eaaf0183880bde68a1862746fa32a.jpg to grayscale.
# Converted trashnet-mixed2-LCS_195_jpg.rf.7e78e07c1541e9db61e047d5184c60bd.jpg to grayscale.
# Converted trashnet-mixed3-HCM_289_jpg.rf.3510db736b03d1685dde51794589992c.jpg to grayscale.
# Converted trashnet-mixed09-16_377_jpg.rf.91d6453b362c311da57cd7897d61d9d7.jpg to grayscale.
# Converted taco-batch_5-000008.jpg to grayscale.
# Converted taco-batch_6-000035.jpg to grayscale.
# Converted trashnet-carton_206_jpg.rf.7a4c8452e7be96dee6662a0b4509f157.jpg to grayscale.
# Converted trashnet-mixed09-16_306_jpg.rf.bbeda39a79084d087cb2f9cb9bf46be5.jpg to grayscale.
# Converted taco-batch_2-000006.jpg to grayscale.
# Converted trashnet-paper_container_100_jpg.rf.1f08a7169a6fea82df9421c2981fb096.jpg to grayscale.
# Converted taco-batch_12-000055.jpg to grayscale.
# Converted taco-batch_15-000076.jpg to grayscale.
# Converted taco-batch_11-000033.jpg to grayscale.
# Converted taco-batch_7-000031.jpg to grayscale.
# Converted taco-batch_12-000020.jpg to grayscale.
# Converted trashnet-mixed2-LCM_260_jpg.rf.f3352d8c6c3bf693af4c38f7bcc07b01.jpg to grayscale.
# Converted trashnet-mixed2-LCS_063_jpg.rf.36f7c2afddd15657b57afbcf42488090.jpg to grayscale.
# Converted taco-batch_2-000088.jpg to grayscale.
# Converted taco-batch_4-000039.jpg to grayscale.
# Converted taco-batch_4-000003.jpg to grayscale.
# Converted trashnet-mixed10-16_80_jpg.rf.862f9cadd2c925da55c3383e12b8e3d9.jpg to grayscale.
# Converted trashnet-2020_0328_72_jpg.rf.5b5d14a8c3df9e67548471eb6b0b594d.jpg to grayscale.
# Converted trashnet-metal_199_jpg.rf.50e9229118baadd68d4a7f1565d260d9.jpg to grayscale.
# Converted trashnet-plastic_container_115_jpg.rf.b3e6dcc2b52e4f7f55bd154959d8d7e4.jpg to grayscale.
# Converted taco-batch_6-000026.jpg to grayscale.
# Converted trashnet-2020_0328_14_jpg.rf.e11587dee0a1adeb405d17bce6bb5c23.jpg to grayscale.
# Converted trashnet-carton_108_jpg.rf.a54e95679eae79f0ef19156e4b4e6965.jpg to grayscale.
# Converted trashnet-plastic_container_025_jpg.rf.1c62072f4d5dab777ec7a277a038eb83.jpg to grayscale.
# Converted trashnet-plastic_container_058_jpg.rf.27907e99f82fbf2d3137d734c5b36115.jpg to grayscale.
# Converted taco-batch_2-000030.jpg to grayscale.
# Converted trashnet-metal_077_jpg.rf.3b9ae5e026c70d29c445e0d4c6375429.jpg to grayscale.
# Converted trashnet-mixed_114_jpg.rf.649c8745bde84ea0a7c67bdfa91153c7.jpg to grayscale.
# Converted taco-batch_9-000081.jpg to grayscale.
# Converted trashnet-2020_0328_83_jpg.rf.2ae74020e9aea12678ef55afdf98b4aa.jpg to grayscale.
# Converted taco-batch_8-000088.jpg to grayscale.
# Converted taco-batch_13-000049.jpg to grayscale.
# Converted taco-batch_4-000052.jpg to grayscale.
# Converted trashnet-mixed10-15-C_58_jpg.rf.e7f334a911c06fcc4712cacd51d93ea2.jpg to grayscale.
# Converted trashnet-metal_225_jpg.rf.8998940978b4409faf2cea40424188bf.jpg to grayscale.
# Converted trashnet-mixed2-LCS_076_jpg.rf.1b27ecaabf4eedb1a9a1fcce9d74a200.jpg to grayscale.
# Converted trashnet-mixed3-HCM_161_jpg.rf.c63d9a3dc868bf6925a681a075eb2220.jpg to grayscale.
# Converted taco-batch_1-000074.jpg to grayscale.
# Converted taco-batch_12-000042.jpg to grayscale.
# Converted trashnet-mixed2-LCS_198_jpg.rf.cbe6d3b0cd340564ea27e1ab30556891.jpg to grayscale.
# Converted trashnet-mixed10-15-C_30_jpg.rf.0dff80b663d3abe523fe0644bfc785b0.jpg to grayscale.
# Converted taco-batch_11-000048.jpg to grayscale.
# Converted trashnet-mixed3-HCS_094_jpg.rf.6b0f7aba451840912ff84f258d7612b3.jpg to grayscale.
# Converted trashnet-mixed09-16_247_jpg.rf.ca4c20055261dcefabf95ca1cd90af93.jpg to grayscale.
# Converted trashnet-plastic_container_054_jpg.rf.e4199befea9bca7aa758cd025f1d40d7.jpg to grayscale.
# Converted trashnet-mixed10-16_22_jpg.rf.d3850b24ee1b8f17f1c415d48e93a63c.jpg to grayscale.
# Converted taco-batch_2-000032.jpg to grayscale.
# Converted trashnet-mixed2-LCM_064_jpg.rf.708d021120d7235fc6c786f2161efee0.jpg to grayscale.
# Converted trashnet-mixed2-LCM_124_jpg.rf.3782d44fe1c634057db619637ebb727b.jpg to grayscale.
# Converted taco-batch_8-000087.jpg to grayscale.
# Converted trashnet-mixed10-15-C_145_jpg.rf.3a39b8af9c19009b8107ef7b7160f436.jpg to grayscale.
# Converted trashnet-mixed2-LCM_046_jpg.rf.9d5e8c54c0b24331ceca38b067f0c041.jpg to grayscale.
# Converted trashnet-mixed3-HCS_156_jpg.rf.41651cf195a67d077147daaba25ed767.jpg to grayscale.
# Converted taco-batch_8-000097.jpg to grayscale.
# Converted taco-batch_2-000037.jpg to grayscale.
# Converted taco-batch_14-000028.jpg to grayscale.
# Converted trashnet-mixed3-HCS_059_jpg.rf.1e1f4edb67ea8b179b152b393b7bede6.jpg to grayscale.
# Converted trashnet-plastic_bottle_011_jpg.rf.39ca26213e670fa507f9c55a9e787b92.jpg to grayscale.
# Converted trashnet-plastic_container_118_jpg.rf.a63bb0221bfc56abd96b1fb4caa6296c.jpg to grayscale.
# Converted trashnet-mixed10-15-C_101_jpg.rf.7ad71029140c3f4bc24af11d5760913f.jpg to grayscale.
# Converted trashnet-mixed10-15-C_333_jpg.rf.995d375421c157f7b28fd9771ff67cd7.jpg to grayscale.
# Converted trashnet-mixed09-16_218_jpg.rf.b1f76831dca78c3459ce306a43817421.jpg to grayscale.
# Converted trashnet-mixed_182_jpg.rf.06c256663d1ad2d6aec67e3316e9fbd4.jpg to grayscale.
# Converted trashnet-metal_250_jpg.rf.35b6b1a34f46a2c37aec9fa019d8e49b.jpg to grayscale.
# Converted trashnet-mixed3-HCM_288_jpg.rf.03b220c29ad1ba6c9f843d1c48a59874.jpg to grayscale.
# Converted trashnet-mixed10-15-C_424_jpg.rf.8fc87145afcde11de5923ac899b18b68.jpg to grayscale.
# Converted taco-batch_1-000007.jpg to grayscale.
# Converted trashnet-mixed2-LCS_036_jpg.rf.6344fa2fe28a2f0a652bfc764daa6c84.jpg to grayscale.
# Converted trashnet-mixed_300_jpg.rf.cfba07e11771f93f27ccf21e625efd77.jpg to grayscale.
# Converted taco-batch_7-000039.jpg to grayscale.
# Converted trashnet-metal_293_jpg.rf.a654acc77d7f440ac7c36e70444abafe.jpg to grayscale.
# Converted trashnet-mixed3-HCM_249_jpg.rf.8f8bcca99129097ebfa3014450084c51.jpg to grayscale.
# Converted trashnet-mixed2-LCM_243_jpg.rf.317fb41852083473b7506b176e232d3d.jpg to grayscale.
# Converted trashnet-mixed3-HCM_157_jpg.rf.bda0e5d924ca4a272acc09d5818c1576.jpg to grayscale.
# Converted trashnet-mixed_090_jpg.rf.8416d4a8f9c83917b562b03b6422da55.jpg to grayscale.
# Converted trashnet-mixed2-LCS_047_jpg.rf.d3e6ba5d1396944787482b87881c1e2d.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_94_jpg.rf.5909067ce30657128f81bcf9476e25a7.jpg to grayscale.
# Converted trashnet-paper_container_026_jpg.rf.0d3151c57e86e13159fc118080ed29a2.jpg to grayscale.
# Converted taco-batch_4-000053.jpg to grayscale.
# Converted trashnet-mixed2-LCM_292_jpg.rf.f6fa806b21e9ab05e4df636e8ee01e17.jpg to grayscale.
# Converted trashnet-mixed09-16_044_jpg.rf.bfc28233342860f62e8299826e8a1d73.jpg to grayscale.
# Converted taco-batch_7-000138.jpg to grayscale.
# Converted trashnet-plastic_container_126_jpg.rf.3ef88b18c7dbb6a1bcf92a6d29167c09.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_19_jpg.rf.611e1150a71ae94be337f24742eea7ef.jpg to grayscale.
# Converted taco-batch_11-000065.jpg to grayscale.
# Converted taco-batch_9-000006.jpg to grayscale.
# Converted taco-batch_7-000082.jpg to grayscale.
# Converted trashnet-mixed2-LCM_276_jpg.rf.c63dd89e205fe06ce493413e03c200fd.jpg to grayscale.
# Converted trashnet-mixed3-HCS_179_jpg.rf.3baf64002b0c7b0fb36166936bcef34e.jpg to grayscale.
# Converted trashnet-mixed3-HCS_115_jpg.rf.6050e31ce84b20becf4e6f87d90f4171.jpg to grayscale.
# Converted trashnet-mixed2-LCM_108_jpg.rf.c693d73c3a51f9b2a553c87543681b9a.jpg to grayscale.
# Converted trashnet-mixed09-16_260_jpg.rf.928af4c76d75041c0894d903bd2253fe.jpg to grayscale.
# Converted trashnet-metal_032_jpg.rf.f96689ff06c1285953a4423541420930.jpg to grayscale.
# Converted trashnet-plastic_bottle_006_jpg.rf.3af0f381a2b7b6d119a06d85d6897975.jpg to grayscale.
# Converted taco-batch_13-000076.jpg to grayscale.
# Converted taco-batch_3-img_4932.jpg to grayscale.
# Converted trashnet-mixed3-HCM_276_jpg.rf.0af7fd3c6e59a504f2e6da4eaaa7975d.jpg to grayscale.
# Converted trashnet-mixed_286_jpg.rf.381c99ef74b9c53a0889a06ae789433a.jpg to grayscale.
# Converted trashnet-mixed_048_jpg.rf.5162bdf257c73f7fc9a3e4267d10c274.jpg to grayscale.
# Converted trashnet-mixed2-LCS_072_jpg.rf.2f8a160527eea7493b3ed58c9fa0bfe1.jpg to grayscale.
# Converted taco-batch_9-000072.jpg to grayscale.
# Converted trashnet-mixed09-16_097_jpg.rf.22330897866fe4c52674d670e1cd0df2.jpg to grayscale.
# Converted trashnet-mixed09-16_367_jpg.rf.336ea1cb84f733c72283267f7d7e2f1d.jpg to grayscale.
# Converted taco-batch_7-000012.jpg to grayscale.
# Converted taco-batch_6-000054.jpg to grayscale.
# Converted trashnet-mixed10-15-C_122_jpg.rf.661817fe6b13af4dbd9ec03fb85ad7d3.jpg to grayscale.
# Converted taco-batch_7-000114.jpg to grayscale.
# Converted trashnet-plastic_container_023_jpg.rf.3fd31c82ecaedd82ce6dcfbb8ef605ed.jpg to grayscale.
# Converted trashnet-mixed2-LCS_061_jpg.rf.28f93f1393161575edeb71b859687f94.jpg to grayscale.
# Converted taco-batch_10-000072.jpg to grayscale.
# Converted trashnet-metal_218_jpg.rf.789ae8fde1ce270ebf45a0d7b36321a8.jpg to grayscale.
# Converted trashnet-2020_0328_42_jpg.rf.202dd7da1b8d4ddd80a6f66b0bc81029.jpg to grayscale.
# Converted taco-batch_12-000094.jpg to grayscale.
# Converted trashnet-mixed10-15-C_452_jpg.rf.309f6da7bf46821dc20d7d5a8e3c6d50.jpg to grayscale.
# Converted taco-batch_3-img_4901.jpg to grayscale.
# Converted trashnet-mixed09-16_274_jpg.rf.9f61c31115e348ceb678f08699b39fa8.jpg to grayscale.
# Converted taco-batch_1-000054.jpg to grayscale.
# Converted taco-batch_15-000012.jpg to grayscale.
# Converted trashnet-mixed_178_jpg.rf.4c19fabacbc9da6df81e558c474a9397.jpg to grayscale.
# Converted trashnet-mixed3-HCM_190_jpg.rf.4600873f597f42ad2f5eb265a384bd34.jpg to grayscale.
# Converted taco-batch_10-000077.jpg to grayscale.
# Converted trashnet-mixed2-LCM_284_jpg.rf.516baa196ff7be0bd234ec20eead4d07.jpg to grayscale.
# Converted trashnet-mixed10-15-C_261_jpg.rf.ed69534e33737b28742a2a92c87ac2a7.jpg to grayscale.
# Converted taco-batch_10-000030.jpg to grayscale.
# Converted trashnet-2020_0328_27_jpg.rf.d532b5a53ae34afe8943bb66c6e28bad.jpg to grayscale.
# Converted trashnet-mixed2-LCM_074_jpg.rf.40584f24ad5ce8fb86a185f6af8cb746.jpg to grayscale.
# Converted trashnet-metal_298_jpg.rf.3b2acb108fc8092aa8cee283c1f30729.jpg to grayscale.
# Converted trashnet-mixed10-15-C_99_jpg.rf.2290fa272a6f22c9c527ba4ec50a1740.jpg to grayscale.
# Converted taco-batch_5-000036.jpg to grayscale.
# Converted trashnet-mixed3-HCM_237_jpg.rf.daf803b4f40ead7e958918976e2efbf6.jpg to grayscale.
# Converted trashnet-mixed3-HCM_141_jpg.rf.e25a44b3bcc1bb347c778babd2836440.jpg to grayscale.
# Converted trashnet-mixed3-HCM_160_jpg.rf.2ca0f53d63f61a9913d3ef585420e1b5.jpg to grayscale.
# Converted taco-batch_2-000090.jpg to grayscale.
# Converted trashnet-mixed10-15-C_286_jpg.rf.4fbf2ed3d82ffbf370f7f15a668bffe5.jpg to grayscale.
# Converted trashnet-plastic_container_050_jpg.rf.78882835c978c070282dc7cc56ddd30f.jpg to grayscale.
# Converted trashnet-mixed10-16_64_jpg.rf.804a0e81268e78f5768d7cac6882e5bd.jpg to grayscale.
# Converted taco-batch_15-000074.jpg to grayscale.
# Converted trashnet-metal_273_jpg.rf.1f40bc04e024fc2dbb4881e95fb77953.jpg to grayscale.
# Converted taco-batch_5-000042.jpg to grayscale.
# Converted trashnet-mixed2-LCS_160_jpg.rf.ce742de007a6caaa03ea9c120be99fad.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_83_jpg.rf.143596d503a32ee1084040118cf90273.jpg to grayscale.
# Converted trashnet-mixed2-LCS_148_jpg.rf.e969cde4a124db27adb28a0d2fcab018.jpg to grayscale.
# Converted trashnet-metal_247_jpg.rf.e1a25465001b894b5e5d6cd2a3a06230.jpg to grayscale.
# Converted trashnet-mixed10-15-C_483_jpg.rf.7f164a55bfc847fe652ab6b32584f0e0.jpg to grayscale.
# Converted taco-batch_9-000017.jpg to grayscale.
# Converted trashnet-metal_044_jpg.rf.2ddd9a4f20eba7f6690a76870352e73f.jpg to grayscale.
# Converted trashnet-mixed_189_jpg.rf.e226317e20ebff04acca113e30cadd41.jpg to grayscale.
# Converted taco-batch_5-000024.jpg to grayscale.
# Converted trashnet-mixed10-15-C_342_jpg.rf.eb1cb2fd1d046701ad0f313c34f42d39.jpg to grayscale.
# Converted trashnet-mixed09-16_203_jpg.rf.9f436213ffd44ce878465e6e1cb51001.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_90_jpg.rf.a132430b47c3b02efa0052621a792d45.jpg to grayscale.
# Converted trashnet-mixed3-HCM_117_jpg.rf.267b558a0e3d897329c0ed4b012d7385.jpg to grayscale.
# Converted trashnet-mixed3-HCS_106_jpg.rf.4373110617494c6ad138eb6b046d197f.jpg to grayscale.
# Converted trashnet-mixed09-16_131_jpg.rf.f8348ad4572510ce6f67a163ce00a0df.jpg to grayscale.
# Converted taco-batch_15-000070.jpg to grayscale.
# Converted taco-batch_5-000112.jpg to grayscale.
# Converted taco-batch_13-000055.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_22_jpg.rf.6bd4314c76d3fc51036821b70f045cdd.jpg to grayscale.
# Converted trashnet-mixed2-LCS_145_jpg.rf.08f9835d8fe9dbf5a45c52bb15dcb30e.jpg to grayscale.
# Converted trashnet-metal_254_jpg.rf.7e4d783039bd0873726eb6cc2019e9c7.jpg to grayscale.
# Converted taco-batch_10-000045.jpg to grayscale.
# Converted trashnet-mixed09-16_223_jpg.rf.3accfd7d80880c6f809d1e09454d5f3f.jpg to grayscale.
# Converted trashnet-plastic_bottle_082_jpg.rf.329019c3c257b293586bf726f21e87f8.jpg to grayscale.
# Converted trashnet-mixed09-16_098_jpg.rf.8068e56d576462982fa47ffb360d16ac.jpg to grayscale.
# Converted trashnet-mixed10-15-C_115_jpg.rf.f38133fb8e6c35c2efd62e283f2adaf3.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_82_jpg.rf.1fe0c6455ba5ffeb003fc5db8a3d8fa2.jpg to grayscale.
# Converted taco-batch_9-000076.jpg to grayscale.
# Converted trashnet-carton_024_jpg.rf.dbb832c3f9aa49bcc5d35cc98f65fab3.jpg to grayscale.
# Converted taco-batch_9-000059.jpg to grayscale.
# Converted taco-batch_6-000001.jpg to grayscale.
# Converted trashnet-mixed10-15-C_350_jpg.rf.be028985bb34c295f8b002438d52f4d3.jpg to grayscale.
# Converted trashnet-mixed10-15-C_299_jpg.rf.fd16c26acbdfde5a5cda347eb7e80d13.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_108_jpg.rf.c131ce749a38bb8808c216bfba11f679.jpg to grayscale.
# Converted taco-batch_13-000042.jpg to grayscale.
# Converted trashnet-mixed3-HCM_145_jpg.rf.99d941ca0bc04cc57f5b9f9f78f5bb34.jpg to grayscale.
# Converted trashnet-carton_205_jpg.rf.3578265e88eea859256cb9969d271d81.jpg to grayscale.
# Converted trashnet-mixed2-LCM_008_jpg.rf.afcb4eadef3bdc4597f199c9a1a8b939.jpg to grayscale.
# Converted trashnet-metal_163_jpg.rf.cf60683adde6fac29d02262c8472ae4f.jpg to grayscale.
# Converted taco-batch_4-000054.jpg to grayscale.
# Converted taco-batch_11-000001.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_122_jpg.rf.780a31652107276cf6b6116353a7f19c.jpg to grayscale.
# Converted taco-batch_5-000089.jpg to grayscale.
# Converted trashnet-metal_074_jpg.rf.35e493c0d46d3f2736f4baaf1f83122d.jpg to grayscale.
# Converted trashnet-mixed10-15-C_460_jpg.rf.72dcf4e0148b30a2106a1affd09a9dac.jpg to grayscale.
# Converted taco-batch_4-000093.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_134_jpg.rf.d665678b988b6491a80c4cb831270a28.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_66_jpg.rf.6fdcb502d675af1a1d5628f1ec92f9f8.jpg to grayscale.
# Converted trashnet-metal_025_jpg.rf.9f610563f587d45840563515f2f8240f.jpg to grayscale.
# Converted taco-batch_15-000006.jpg to grayscale.
# Converted trashnet-mixed3-HCM_219_jpg.rf.bad1a22e7f1da0ef1ae14bab6f98ef92.jpg to grayscale.
# Converted trashnet-mixed09-16_399_jpg.rf.d24f345b15f75dcb5b86d053a367a4d2.jpg to grayscale.
# Converted trashnet-mixed2-LCM_129_jpg.rf.c4698a8a46625b44124ce46c8bd918b1.jpg to grayscale.
# Converted trashnet-mixed3-HCS_188_jpg.rf.1480533bae6740eda36f6fd126311c1e.jpg to grayscale.
# Converted trashnet-mixed3-HCM_268_jpg.rf.523d912c04f97478092688cc40434b99.jpg to grayscale.
# Converted taco-batch_13-000012.jpg to grayscale.
# Converted trashnet-mixed3-HCM_136_jpg.rf.1d55ba00f0b38394bdd0603bcad0710b.jpg to grayscale.
# Converted trashnet-plastic_container_046_jpg.rf.02671d4f889262688564d61fc5619419.jpg to grayscale.
# Converted trashnet-mixed2-LCM_272_jpg.rf.b5dfcb4a609a07a7d64a1dc94cf3b35a.jpg to grayscale.
# Converted taco-batch_8-000085.jpg to grayscale.
# Converted trashnet-paper_container_004_jpg.rf.d1908aea8a32291794b53ff37b1ef67b.jpg to grayscale.
# Converted taco-batch_12-000081.jpg to grayscale.
# Converted taco-batch_11-000037.jpg to grayscale.
# Converted trashnet-plastic_container_136_jpg.rf.f9a55db3fad1672b2562bfbcac4385f7.jpg to grayscale.
# Converted taco-batch_14-000006.jpg to grayscale.
# Converted trashnet-plastic_container_034_jpg.rf.f9c9ce97087bca7d8831b1e1fd787501.jpg to grayscale.
# Converted trashnet-plastic_bottle_049_jpg.rf.5a81173e6b3d7e7801659d3a93de2d1a.jpg to grayscale.
# Converted taco-batch_13-000032.jpg to grayscale.
# Converted trashnet-mixed10-15-C_295_jpg.rf.fb58212b035aa224686f04536f5354dd.jpg to grayscale.
# Converted trashnet-metal_115_jpg.rf.e956623ab7d543d7b50f9abdbe197339.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_17_jpg.rf.b0aa0a2e96dbb797a99b80adf92d15b4.jpg to grayscale.
# Converted taco-batch_6-000097.jpg to grayscale.
# Converted trashnet-2020_0328_70_jpg.rf.be15089bfea1145dcc9878784335abba.jpg to grayscale.
# Converted trashnet-mixed3-HCM_290_jpg.rf.d97e35578cf7ec7ba7ec73c4d280d1be.jpg to grayscale.
# Converted trashnet-mixed_020_jpg.rf.ca02601db41c3e0336c765c21175fba3.jpg to grayscale.
# Converted trashnet-2020_0328_28_jpg.rf.b897111bd34c6ef6e105316713450093.jpg to grayscale.
# Converted trashnet-mixed10-15-C_01_jpg.rf.082b97cf1e7a1452b1cc6f5ed5fd9aec.jpg to grayscale.
# Converted trashnet-mixed3-HCM_050_jpg.rf.91ca32ff0458998496a4ce3397caa83f.jpg to grayscale.
# Converted trashnet-mixed2-LCS_025_jpg.rf.20a5b0c613b329366e1ec0d89a3c2b97.jpg to grayscale.
# Converted taco-batch_1-000115.jpg to grayscale.
# Converted trashnet-mixed_128_jpg.rf.8ecf6298f7a8dd023227e80ece768b1b.jpg to grayscale.
# Converted trashnet-mixed09-16_117_jpg.rf.e3e4fcbc22ae59ff7473a777b8673676.jpg to grayscale.
# Converted taco-batch_6-000003.jpg to grayscale.
# Converted taco-batch_11-000069.jpg to grayscale.
# Converted taco-batch_1-000027.jpg to grayscale.
# Converted taco-batch_11-000024.jpg to grayscale.
# Converted trashnet-paper_container_118_jpg.rf.93d66db316f2a05ec7e2fb614ae07d2d.jpg to grayscale.
# Converted trashnet-carton_079_jpg.rf.5166d23bd2989e71ec17494a0fee7be9.jpg to grayscale.
# Converted trashnet-mixed10-15-C_38_jpg.rf.aae8b7001a089994c6a421d5b6714f95.jpg to grayscale.
# Converted trashnet-carton_026_jpg.rf.df7ad4213d5735789c37c85a781c5ac9.jpg to grayscale.
# Converted taco-batch_3-img_4929.jpg to grayscale.
# Converted taco-batch_11-000027.jpg to grayscale.
# Converted trashnet-mixed3-HCS_126_jpg.rf.07f5a58a050d075fb46e709d935fd109.jpg to grayscale.
# Converted trashnet-mixed09-16_307_jpg.rf.c1e7ba71be7481a2fe519c60aa3d2136.jpg to grayscale.
# Converted taco-batch_2-000071.jpg to grayscale.
# Converted trashnet-paper_container_012_jpg.rf.098490ad0db866c8133459f02db45305.jpg to grayscale.
# Converted taco-batch_11-000038.jpg to grayscale.
# Converted trashnet-mixed3-HCS_124_jpg.rf.60487ea798a09fed1b83fb59e0f1b3a5.jpg to grayscale.
# Converted trashnet-carton_008_jpg.rf.3bed932fb923e1d1a4714616023fb876.jpg to grayscale.
# Converted trashnet-mixed2-LCM_068_jpg.rf.8485fb9e097eee48a2ecb84a1b593ded.jpg to grayscale.
# Converted taco-batch_6-000033.jpg to grayscale.
# Converted trashnet-mixed_093_jpg.rf.93248cdd2393efab93ab9a7e6bec95cd.jpg to grayscale.
# Converted trashnet-mixed2-LCS_008_jpg.rf.8d436c03f7503a1c0689309926c24efa.jpg to grayscale.
# Converted trashnet-mixed3-HCM_091_jpg.rf.5ee2b2ab284fda337f50c9509aa8c218.jpg to grayscale.
# Converted trashnet-mixed10-16_29_jpg.rf.4e797616df0cb918d381840238552467.jpg to grayscale.
# Converted trashnet-mixed09-16_347_jpg.rf.931449f2dda5fa5829178a3892470ad1.jpg to grayscale.
# Converted trashnet-mixed10-16_87_jpg.rf.b66424a91b3a433cbe1f0e0b94052428.jpg to grayscale.
# Converted trashnet-mixed3-HCS_104_jpg.rf.85f8dc6d516931491e3eb08d6d488892.jpg to grayscale.
# Converted taco-batch_4-000085.jpg to grayscale.
# Converted trashnet-paper_container_008_jpg.rf.8b8a4a07f293067042b20f854bb93901.jpg to grayscale.
# Converted taco-batch_8-000096.jpg to grayscale.
# Converted taco-batch_5-000083.jpg to grayscale.
# Converted trashnet-mixed2-LCM_287_jpg.rf.17e3c5c5980665c49cfd8cfdcf9bf468.jpg to grayscale.
# Converted trashnet-paper_container_094_jpg.rf.22f52b4668ad371af204d6f8df0a2137.jpg to grayscale.
# Converted taco-batch_3-img_4917.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_60_jpg.rf.5079a23a3f2b908d7ff12e3710f65286.jpg to grayscale.
# Converted taco-batch_13-000077.jpg to grayscale.
# Converted trashnet-2020_0328_73_jpg.rf.e713bdcd0e23d8fa295c6784f4cdf259.jpg to grayscale.
# Converted taco-batch_4-000006.jpg to grayscale.
# Converted trashnet-mixed3-HCM_236_jpg.rf.7cb72db1c93bfaff79ad8b6f3e20b76f.jpg to grayscale.
# Converted taco-batch_5-000091.jpg to grayscale.
# Converted trashnet-mixed10-15-C_298_jpg.rf.9d1893082ab9427ac4e3d298b4fae26f.jpg to grayscale.
# Converted taco-batch_7-000101.jpg to grayscale.
# Converted taco-batch_2-000081.jpg to grayscale.
# Converted trashnet-mixed3-HCM_292_jpg.rf.e8a86aa125329eaca98459377d1251c3.jpg to grayscale.
# Converted trashnet-mixed2-LCM_170_jpg.rf.e419306196d3f3ca780ef605a1cfc7a8.jpg to grayscale.
# Converted trashnet-mixed09-16_245_jpg.rf.0d12a4b370c6dbf6490251fc3f1ea9fc.jpg to grayscale.
# Converted trashnet-mixed_164_jpg.rf.48fd7cb220465d2e5d02976bd3edba6e.jpg to grayscale.
# Converted trashnet-mixed09-16_121_jpg.rf.84b22d52f56233d43041b587defbaa16.jpg to grayscale.
# Converted taco-batch_9-000034.jpg to grayscale.
# Converted trashnet-mixed2-LCM_175_jpg.rf.5c5a698b2f638b3b6821edc6b642f75c.jpg to grayscale.
# Converted trashnet-carton_181_jpg.rf.56bfd208476e9ccc510d5114209b6012.jpg to grayscale.
# Converted trashnet-paper_container_037_jpg.rf.de82358cff3dd73d7d583b9fe0373090.jpg to grayscale.
# Converted taco-batch_13-000094.jpg to grayscale.
# Converted trashnet-mixed10-15-C_220_jpg.rf.2b35b8d0bba541b6ca2c4323dd3db4da.jpg to grayscale.
# Converted trashnet-metal_114_jpg.rf.406377f37930b4f92c866b7bb9970312.jpg to grayscale.
# Converted taco-batch_14-000063.jpg to grayscale.
# Converted trashnet-mixed2-LCM_019_jpg.rf.936b283cb49273dbee75f5c77f35f973.jpg to grayscale.
# Converted trashnet-mixed2-LCS_126_jpg.rf.69e30cfa9ee617400899eb0168409058.jpg to grayscale.
# Converted trashnet-metal_084_jpg.rf.0fe4d21469d94bca77f729b6e15b3f11.jpg to grayscale.
# Converted trashnet-mixed3-HCS_086_jpg.rf.e184d24094b5256e931a3d381bd88219.jpg to grayscale.
# Converted trashnet-mixed10-15-C_219_jpg.rf.b244bf16e0c9b673775668f5b68f1219.jpg to grayscale.
# Converted trashnet-mixed09-16_271_jpg.rf.a1a33d01dcdf6837763760b7b9f3f16a.jpg to grayscale.
# Converted trashnet-2020_0328_22_jpg.rf.339e6890866751877f2515dae2218498.jpg to grayscale.
# Converted trashnet-2020_0328_10_jpg.rf.a21924a1fa4543aacf833dadf07fac33.jpg to grayscale.
# Converted trashnet-mixed2-LCM_192_jpg.rf.fa2e529734dbbde6de2e0e8560157c9b.jpg to grayscale.
# Converted taco-batch_7-000087.jpg to grayscale.
# Converted taco-batch_6-000057.jpg to grayscale.
# Converted trashnet-mixed_231_jpg.rf.d3fdd9be6deece6183cef31dac0a781b.jpg to grayscale.
# Converted trashnet-mixed_237_jpg.rf.c1546e2c0d7dcd7e3e5e8b6308dc4c31.jpg to grayscale.
# Converted trashnet-mixed2-LCS_108_jpg.rf.9d6d41cbb0bf6ebdcfef6a7623ecf74d.jpg to grayscale.
# Converted taco-batch_14-000082.jpg to grayscale.
# Converted taco-batch_3-img_5037.jpg to grayscale.
# Converted trashnet-mixed09-16_014_jpg.rf.c7182137e6bf139f9c7076d7fd52675a.jpg to grayscale.
# Converted trashnet-mixed3-HCM_127_jpg.rf.d0974d51bee86f73c2b5af327d76d64b.jpg to grayscale.
# Converted trashnet-mixed3-HCM_174_jpg.rf.5ac40b14b45470122d396573b2c9f490.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_50_jpg.rf.7ced583294094f27aa837117a6b9ff08.jpg to grayscale.
# Converted trashnet-mixed_134_jpg.rf.aba7278b57870435ab465c4ab4c2e134.jpg to grayscale.
# Converted trashnet-mixed3-HCS_045_jpg.rf.3e5ddb5ee53398edacb7e7718f5208d2.jpg to grayscale.
# Converted trashnet-metal_041_jpg.rf.8bc012bec668e102323f1c62468db7a2.jpg to grayscale.
# Converted taco-batch_11-000029.jpg to grayscale.
# Converted trashnet-mixed2-LCM_208_jpg.rf.772bae4d06be4214fe2c27696e4b5af2.jpg to grayscale.
# Converted trashnet-mixed2-LCM_042_jpg.rf.48d7117aff85d1fc56b9e69161367471.jpg to grayscale.
# Converted taco-batch_5-000014.jpg to grayscale.
# Converted trashnet-plastic_bottle_033_jpg.rf.e2538e1ba11a8c9f7ebf93e4f2f95003.jpg to grayscale.
# Converted trashnet-mixed3-HCM_264_jpg.rf.1ebfb25a3f0241b80709b7d15fd8edb6.jpg to grayscale.
# Converted taco-batch_7-000080.jpg to grayscale.
# Converted trashnet-plastic_container_031_jpg.rf.5c0075428bec1a7276567fd822ed2c83.jpg to grayscale.
# Converted trashnet-plastic_bottle_039_jpg.rf.ec20c6390ed9bc9ef26111f24ec10a21.jpg to grayscale.
# Converted taco-batch_9-000086.jpg to grayscale.
# Converted trashnet-paper_container_091_jpg.rf.e1d355692dd8e49edb775df3dbd2e5f2.jpg to grayscale.
# Converted taco-batch_7-000141.jpg to grayscale.
# Converted trashnet-metal_183_jpg.rf.e2b015b89b80a2d14dd16cf6cc2dbcf4.jpg to grayscale.
# Converted taco-batch_6-000050.jpg to grayscale.
# Converted trashnet-carton_071_jpg.rf.4c8ad1beaa5715540d096d52c469b999.jpg to grayscale.
# Converted trashnet-metal_148_jpg.rf.f35cf3dc1eda7450f1c379bf673ae954.jpg to grayscale.
# Converted taco-batch_3-img_4868.jpg to grayscale.
# Converted taco-batch_1-000035.jpg to grayscale.
# Converted trashnet-mixed3-HCS_185_jpg.rf.3eb76aec3b5e4199f28b6a368082e83b.jpg to grayscale.
# Converted trashnet-plastic_bottle_003_jpg.rf.42ef365b78e5d6f66051292871bf449b.jpg to grayscale.
# Converted taco-batch_4-000019.jpg to grayscale.
# Converted trashnet-mixed10-15-C_230_jpg.rf.0249a11676fc3f56288b2063210a9f18.jpg to grayscale.
# Converted taco-batch_11-000095.jpg to grayscale.
# Converted taco-batch_14-000057.jpg to grayscale.
# Converted trashnet-mixed10-15-C_170_jpg.rf.bedbd742e8d56ebec650984a6c9ffe67.jpg to grayscale.
# Converted trashnet-mixed2-LCS_099_jpg.rf.7bbc97ee77aad2bae1cf02b6c0745c33.jpg to grayscale.
# Converted trashnet-mixed2-LCS_163_jpg.rf.963d3a0f945763a5218b0a1abc8cb657.jpg to grayscale.
# Converted trashnet-mixed10-15-C_143_jpg.rf.d9f32741179cee505ccf2c07ce711b93.jpg to grayscale.
# Converted trashnet-mixed2-LCS_199_jpg.rf.14e346b35e7f8c4bfa581398f0f30c80.jpg to grayscale.
# Converted trashnet-mixed3-HCM_100_jpg.rf.328a5d38b63099fd57ddae6e2dd67ba8.jpg to grayscale.
# Converted trashnet-mixed2-LCM_045_jpg.rf.853efca6e565750e799b642c2785eb64.jpg to grayscale.
# Converted trashnet-mixed09-16_145_jpg.rf.3e2a5931f658d9a4dd144d0e81996888.jpg to grayscale.
# Converted taco-batch_12-000008.jpg to grayscale.
# Converted trashnet-metal_073_jpg.rf.d8ef8684f8e556e1dc79f8573b7283d6.jpg to grayscale.
# Converted trashnet-mixed_033_jpg.rf.89e53a96a19850b1c457ae8b5797587a.jpg to grayscale.
# Converted trashnet-mixed3-HCS_111_jpg.rf.64e4eeffa67996c9e91eda4511424f0f.jpg to grayscale.
# Converted taco-batch_1-000096.jpg to grayscale.
# Converted trashnet-carton_150_jpg.rf.0d5c532e15396970364d2a4d699e6650.jpg to grayscale.
# Converted trashnet-metal_117_jpg.rf.ac1358b911bf94dd068732bd39b41669.jpg to grayscale.
# Converted trashnet-mixed2-LCS_098_jpg.rf.a445f8cd2a2a76e4c7af49e40abc92b5.jpg to grayscale.
# Converted trashnet-mixed09-16_326_jpg.rf.58a4b69b6974f086748129ce09354537.jpg to grayscale.
# Converted trashnet-mixed3-HCM_170_jpg.rf.61697d7a9cc40182651d9ce7539eb7a5.jpg to grayscale.
# Converted trashnet-plastic_container_010_jpg.rf.2705bbe3cfa6e731f0ce154c75b33532.jpg to grayscale.
# Converted trashnet-mixed2-LCM_201_jpg.rf.a67a0f5892764d4e4b08db995000824e.jpg to grayscale.
# Converted taco-batch_14-000031.jpg to grayscale.
# Converted trashnet-carton_173_jpg.rf.b7511657b2936575b55dbe9cf8fe19f9.jpg to grayscale.
# Converted trashnet-2020_0328_12_jpg.rf.a4fb568a47c0acfb9e6e4c1280236f2e.jpg to grayscale.
# Converted trashnet-mixed2-LCM_018_jpg.rf.b868d6525c777d40dc20f5e9bcec0596.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_37_jpg.rf.5d555e6223bffdc425217a06146223fe.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_02_jpg.rf.396639c875b1fd1e7f3ccf5047ad60fd.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_92_jpg.rf.78e7e9c367fb72f4dea3f35a596648c4.jpg to grayscale.
# Converted trashnet-mixed10-15-C_297_jpg.rf.334f36c3ca01b7ca8467b5e678aba533.jpg to grayscale.
# Converted taco-batch_7-000095.jpg to grayscale.
# Converted trashnet-mixed10-15-C_185_jpg.rf.aed05341640478942f2b379a6a9b5040.jpg to grayscale.
# Converted taco-batch_12-000040.jpg to grayscale.
# Converted trashnet-mixed2-LCM_001_jpg.rf.573ff1ba91f0391965230eefc62548c9.jpg to grayscale.
# Converted trashnet-mixed2-LCS_153_jpg.rf.34885f0303be67a8828520852631125a.jpg to grayscale.
# Converted trashnet-mixed10-16_23_jpg.rf.45a1c8aab1775cfbbeb70cb70b6ca386.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_76_jpg.rf.b58f0919b9085515e95e3bc99a535ab3.jpg to grayscale.
# Converted trashnet-plastic_container_110_jpg.rf.218d405c95d77a0db05af33ee43aeeaf.jpg to grayscale.
# Converted trashnet-mixed09-16_083_jpg.rf.1a80aa1ae5420709e205d16561dca708.jpg to grayscale.
# Converted trashnet-mixed10-16_50_jpg.rf.89f339abf1e077e8c955da80bdf53abb.jpg to grayscale.
# Converted trashnet-plastic_container_060_jpg.rf.b38f8ec9ee29938eda38b221b2b03d4c.jpg to grayscale.
# Converted trashnet-mixed_086_jpg.rf.993eb77bc82f32aa0503003bb58aad29.jpg to grayscale.
# Converted trashnet-mixed10-15-C_406_jpg.rf.97528cf783b665462fa5831b1ef8989e.jpg to grayscale.
# Converted trashnet-mixed09-16_106_jpg.rf.fa897dac9a62bb0fb3a61dc1c99f616d.jpg to grayscale.
# Converted trashnet-mixed2-LCM_138_jpg.rf.091221be7351f8846f47c5b9b548ebb1.jpg to grayscale.
# Converted trashnet-metal_027_jpg.rf.4864599f97e2e4622a3cdafdd8a24215.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_20_jpg.rf.329cf15884ddc64bd52e43c9245f0778.jpg to grayscale.
# Converted taco-batch_10-000028.jpg to grayscale.
# Converted taco-batch_11-000098.jpg to grayscale.
# Converted trashnet-mixed09-16_208_jpg.rf.c90e3bc74ced62816d884fa9d7f33a57.jpg to grayscale.
# Converted taco-batch_6-000029.jpg to grayscale.
# Converted trashnet-2020_0328_98_jpg.rf.39c76f7b7e9775b0f381c188c3598b16.jpg to grayscale.
# Converted trashnet-mixed09-16_303_jpg.rf.64792752445ecbe9ae6dd50d6ef76e87.jpg to grayscale.
# Converted trashnet-mixed10-16_41_jpg.rf.795198daf7769aae450ddf33d9804bb6.jpg to grayscale.
# Converted taco-batch_15-000080.jpg to grayscale.
# Converted taco-batch_4-000086.jpg to grayscale.
# Converted trashnet-mixed2-LCS_192_jpg.rf.5dd97e07b6ba9d64fa5967e150ade17d.jpg to grayscale.
# Converted taco-batch_1-000073.jpg to grayscale.
# Converted taco-batch_6-000083.jpg to grayscale.
# Converted trashnet-paper_container_031_jpg.rf.4fca7f15c880d1aa049d527dde97024a.jpg to grayscale.
# Converted trashnet-mixed10-15-C_376_jpg.rf.1107e3de3fe2dc4d435d18913786aa04.jpg to grayscale.
# Converted trashnet-mixed2-LCM_130_jpg.rf.ad5e1c4751e9ca63bb73ed0f31b336f9.jpg to grayscale.
# Converted taco-batch_13-000050.jpg to grayscale.
# Converted taco-batch_12-000063.jpg to grayscale.
# Converted taco-batch_15-000068.jpg to grayscale.
# Converted trashnet-mixed3-HCS_205_jpg.rf.da1f45f28a4565ae1f098c18b1deec55.jpg to grayscale.
# Converted taco-batch_13-000001.jpg to grayscale.
# Converted taco-batch_13-000066.jpg to grayscale.
# Converted trashnet-metal_229_jpg.rf.2a607b7e704220a8e545469d3bac6f3c.jpg to grayscale.
# Converted trashnet-mixed09-16_022_jpg.rf.5db71cdd7d77110f714e675372370fe2.jpg to grayscale.
# Converted taco-batch_2-000016.jpg to grayscale.
# Converted trashnet-mixed09-16_181_jpg.rf.2404866a8490288247256e8076d3bab2.jpg to grayscale.
# Converted trashnet-2020_0328_99_jpg.rf.963cb3f2a29f76a07446d3ed8709983f.jpg to grayscale.
# Converted taco-batch_5-000113.jpg to grayscale.
# Converted trashnet-mixed10-15-C_28_jpg.rf.ca258015a02fe04ae60a91114a483a32.jpg to grayscale.
# Converted trashnet-mixed10-15-C_147_jpg.rf.5b719ecbeae297f063a1106643fdc64c.jpg to grayscale.
# Converted trashnet-mixed_122_jpg.rf.44022c4b1447409c7e33925025ea54f9.jpg to grayscale.
# Converted taco-batch_4-000034.jpg to grayscale.
# Converted trashnet-mixed10-15-C_157_jpg.rf.9a9df72fda4262ed409c73c75f5f91a6.jpg to grayscale.
# Converted trashnet-mixed3-HCS_015_jpg.rf.b350b92f22bdead49417a6ffba036fc7.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_68_jpg.rf.862929da00902a81e49e6117deff8b3e.jpg to grayscale.
# Converted trashnet-mixed09-16_073_jpg.rf.33943a6192161d69444dfcb956965d5a.jpg to grayscale.
# Converted trashnet-mixed09-16_186_jpg.rf.06851b1d0a5e10fddae4113108f07979.jpg to grayscale.
# Converted trashnet-mixed10-15-C_192_jpg.rf.ef257afe80edeb33bfd3b6efc15c9914.jpg to grayscale.
# Converted trashnet-metal_096_jpg.rf.44779194d878c1d764ea42e500e47df7.jpg to grayscale.
# Converted trashnet-paper_container_047_jpg.rf.b11cff2c513f2bf81bca3d3e3efd90cd.jpg to grayscale.
# Converted trashnet-metal_228_jpg.rf.64b38028e2ff441404377384ecb16607.jpg to grayscale.
# Converted trashnet-mixed3-HCS_065_jpg.rf.94d67e19ca6b4959e5eb5eeeb485088f.jpg to grayscale.
# Converted taco-batch_6-000060.jpg to grayscale.
# Converted taco-batch_7-000092.jpg to grayscale.
# Converted trashnet-metal_248_jpg.rf.ba70a04822b4593e635006b54e29ab2b.jpg to grayscale.
# Converted trashnet-2020_0328_0_jpg.rf.788ae8fde915040f02e48c2ad1f2a53c.jpg to grayscale.
# Converted trashnet-mixed3-HCM_086_jpg.rf.8701bb17f00f7151f82b3a012bfef2bf.jpg to grayscale.
# Converted trashnet-plastic_container_135_jpg.rf.933bea958e5c7dc9f46e177bf96c20ae.jpg to grayscale.
# Converted trashnet-metal_080_jpg.rf.527f8a8fecd0945009ea3bc976a30606.jpg to grayscale.
# Converted taco-batch_1-000094.jpg to grayscale.
# Converted taco-batch_7-000015.jpg to grayscale.
# Converted trashnet-mixed2-LCS_165_jpg.rf.fff5b047eae7c726ba905f31723b79b5.jpg to grayscale.
# Converted taco-batch_10-000022.jpg to grayscale.
# Converted trashnet-plastic_bottle_053_jpg.rf.57fccf94f399e75e6d9912ff9c23a7d7.jpg to grayscale.
# Converted taco-batch_14-000012.jpg to grayscale.
# Converted trashnet-mixed10-16_51_jpg.rf.0a55e2412a038c996f1439b05f6a1823.jpg to grayscale.
# Converted trashnet-mixed09-16_114_jpg.rf.07bcb4faf7f57eb48bff370077b90f51.jpg to grayscale.
# Converted trashnet-mixed10-15-C_43_jpg.rf.e2c500a9c11dbb87b9444c6b74ca94d2.jpg to grayscale.
# Converted trashnet-mixed2-LCM_271_jpg.rf.8093f66a8d71e224a3d34a7214403d4a.jpg to grayscale.
# Converted trashnet-mixed3-HCS_128_jpg.rf.7980b41e1a95aedd258cb5e2532e8524.jpg to grayscale.
# Converted taco-batch_2-000052.jpg to grayscale.
# Converted trashnet-mixed3-HCS_135_jpg.rf.bbbc1376affa018ba603ac5656ab2fa5.jpg to grayscale.
# Converted trashnet-mixed3-HCM_266_jpg.rf.d08ee1ee6e6824b92006fc0f76462d28.jpg to grayscale.
# Converted trashnet-metal_058_jpg.rf.ed689f1de40a6c47afe25542ad8d32bf.jpg to grayscale.
# Converted trashnet-plastic_container_064_jpg.rf.bf30fa9590f1dbf67c325371f13b74d2.jpg to grayscale.
# Converted taco-batch_3-img_5064.jpg to grayscale.
# Converted trashnet-2020_0328_52_jpg.rf.2a1fc85940b6e6f5e11e0de6abcd041c.jpg to grayscale.
# Converted taco-batch_1-000059.jpg to grayscale.
# Converted trashnet-mixed2-LCS_050_jpg.rf.aef1fdc0cba494789f7346815d6b6406.jpg to grayscale.
# Converted trashnet-mixed2-LCS_125_jpg.rf.a60bd6c18aa2f8b8b06befdc19cb3bd2.jpg to grayscale.
# Converted trashnet-2020_0328_16_jpg.rf.0c766bd89a1860a7f8d14240f81451b5.jpg to grayscale.
# Converted trashnet-mixed3-HCS_090_jpg.rf.0358f28c30028006202cfcd289849ef8.jpg to grayscale.
# Converted taco-batch_11-000084.jpg to grayscale.
# Converted trashnet-mixed2-LCS_039_jpg.rf.d4cd10f04281a99635908c9d2b751a40.jpg to grayscale.
# Converted taco-batch_1-000088.jpg to grayscale.
# Converted trashnet-mixed3-HCS_085_jpg.rf.e4ba906322c88bab36bc7dedc67f3219.jpg to grayscale.
# Converted taco-batch_10-000012.jpg to grayscale.
# Converted trashnet-plastic_container_029_jpg.rf.c21353a41fd312c184537d13c67d4285.jpg to grayscale.
# Converted trashnet-mixed10-15-C_395_jpg.rf.28655167874cfbd16524ca7bb6da0aff.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_53_jpg.rf.aad3e436f2c482844786e2cd013b9c36.jpg to grayscale.
# Converted trashnet-mixed3-HCM_274_jpg.rf.ba068d0032d8297b20bd1e04efbfb29b.jpg to grayscale.
# Converted taco-batch_14-000036.jpg to grayscale.
# Converted trashnet-metal_187_jpg.rf.b94dafba771706d03d96aee347ba0778.jpg to grayscale.
# Converted trashnet-metal_257_jpg.rf.6ebdff306bb451902197691419bb1e00.jpg to grayscale.
# Converted taco-batch_10-000067.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_77_jpg.rf.44960bce50ac452b89ea6ea51f69d059.jpg to grayscale.
# Converted trashnet-mixed_002_jpg.rf.799ed9f44319a62ec722ac962bdc4606.jpg to grayscale.
# Converted trashnet-mixed3-HCS_171_jpg.rf.e8db23b98c639e0d76d04bf1ab0f36df.jpg to grayscale.
# Converted trashnet-carton_068_jpg.rf.3209c4c90392f4af669debedaa921385.jpg to grayscale.
# Converted trashnet-metal_007_jpg.rf.039b1dfc605f79a75e7ab98e6af562d1.jpg to grayscale.
# Converted trashnet-mixed09-16_322_jpg.rf.bfaf15c4cbc3f584395caf7df53fe78e.jpg to grayscale.
# Converted trashnet-mixed10-15-C_457_jpg.rf.e38e4627f4101151e1ab30fb93653d64.jpg to grayscale.
# Converted taco-batch_8-000028.jpg to grayscale.
# Converted trashnet-mixed2-LCM_159_jpg.rf.fbc51b818436a97331d9b98c9a174ece.jpg to grayscale.
# Converted trashnet-mixed2-LCM_082_jpg.rf.e83f369c20def8557df338a3f93a945e.jpg to grayscale.
# Converted trashnet-mixed_047_jpg.rf.d55300a19a00560a382e3cee5e2a2e31.jpg to grayscale.
# Converted trashnet-carton_202_jpg.rf.0bd4d8eca6bbaaea3b27cfe5a2e8db7a.jpg to grayscale.
# Converted trashnet-mixed3-HCM_098_jpg.rf.0234e01974533ee84fddc313a5902501.jpg to grayscale.
# Converted trashnet-2020_0328_56_jpg.rf.bd694ba97b5e0872094d5b7f4684ee95.jpg to grayscale.
# Converted trashnet-mixed10-15-C_131_jpg.rf.045720d74f76a24bd4776b37e4763841.jpg to grayscale.
# Converted trashnet-mixed10-16_85_jpg.rf.0aa646adbe61f877f13fe440fb6774a3.jpg to grayscale.
# Converted trashnet-mixed09-16_270_jpg.rf.c5039c34cd73e7f4ed1d858e3a773535.jpg to grayscale.
# Converted trashnet-carton_137_jpg.rf.ec1af2e8342ac7dc9033ee3db1767743.jpg to grayscale.
# Converted trashnet-mixed09-16_147_jpg.rf.77256dd0d0f69901d8181d09c84bc55f.jpg to grayscale.
# Converted trashnet-metal_126_jpg.rf.537587866fdb683101480b1eff24aaea.jpg to grayscale.
# Converted trashnet-carton_204_jpg.rf.35d0ab023260719de07b1b16eb1105d6.jpg to grayscale.
# Converted taco-batch_5-000063.jpg to grayscale.
# Converted taco-batch_8-000082.jpg to grayscale.
# Converted trashnet-mixed10-15-UC_55_jpg.rf.7373ecca891eb299286ff82d865ac1c2.jpg to grayscale.
# Converted trashnet-mixed10-16_35_jpg.rf.af21815a5e1eba9e29cd45d12cdfa946.jpg to grayscale.
# Converted taco-batch_14-000067.jpg to grayscale.
# Converted taco-batch_8-000042.jpg to grayscale.
